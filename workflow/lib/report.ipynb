# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Project Report\n",
#     "\n",
#     "This report summarizes the results of the sequencing analysis pipeline."
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 1. MultiQC Fastp Report (FASTQ)\n",
#     "\n",
#     "<iframe src=\"./01_multiqc/multiqc_report.html\" width=\"100%\" height=\"800\"></iframe>"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 2. Mapping and Target Region Statistics"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "execution_count": null,
#    "outputs": [],
#    "source": [
#     "# Show mapping summary\n",
#     "with open('./02_map/07_summary/summary_target_dedup.txt') as f:\n",
#     "    print(f.read())"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### Additional Mapping Reports\n",
#     "- [BQSR Stats Report](./02_map/07_summary/multiqc_bqsr_stats_report.html)\n",
#     "- [BQSR Idxstats Report](./02_map/07_summary/multiqc_bqsr_idxstats_report.html)\n",
#     "- [BQSR Flagstat Report](./02_map/07_summary/multiqc_bqsr_flagstat_report.html)"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 3. Variant Results"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "execution_count": null,
#    "outputs": [],
#    "source": [
#     "import glob\n",
#     "from IPython.display import Image, display\n",
#     "\n",
#     "# Show Venn diagrams\n",
#     "venn_files = sorted(glob.glob('./04_overlap/01_plot/*.venn.diagram.png'))\n",
#     "for venn in venn_files:\n",
#     "    print(f\"### {venn.split('/')[-1]}\")\n",
#     "    display(Image(filename=venn))"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "execution_count": null,
#    "outputs": [],
#    "source": [
#     "# Show scatter plots\n",
#     "scatter_files = sorted(glob.glob('./04_overlap/01_plot/*.scatter.png'))\n",
#     "for scatter in scatter_files:\n",
#     "    print(f\"### {scatter.split('/')[-1]}\")\n",
#     "    display(Image(filename=scatter))"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.8"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 2
# }
